# %% [markdown]
# # Loading data

# %%
#loading dataset
#install.packages("MatchIt")
library(MatchIt)
dataset <- lalonde
# Out:
# Warning message:
# "package 'MatchIt' was built under R version 3.6.3"

# %%
dataset
# Out:
#         treat age educ race   married nodegree re74 re75 re78
# NSW1    1     37  11   black  1       1        0    0     9930.0460
# NSW2    1     22   9   hispan 0       1        0    0     3595.8940
# NSW3    1     30  12   black  0       0        0    0    24909.4500
# NSW4    1     27  11   black  0       1        0    0     7506.1460
# NSW5    1     33   8   black  0       1        0    0      289.7899
# NSW6    1     22   9   black  0       1        0    0     4056.4940
# NSW7    1     23  12   black  0       0        0    0        0.0000
# NSW8    1     32  11   black  0       1        0    0     8472.1580
# NSW9    1     22  16   black  0       0        0    0     2164.0220
# NSW10   1     33  12   white  1       0        0    0    12418.0700
# NSW11   1     19   9   black  0       1        0    0     8173.9080
# NSW12   1     21  13   black  0       0        0    0    17094.6400
# NSW13   1     18   8   black  0       1        0    0        0.0000
# NSW14   1     27  10   black  1       1        0    0    18739.9300
# NSW15   1     17   7   black  0       1        0    0     3023.8790
# NSW16   1     19  10   black  0       1        0    0     3228.5030
# NSW17   1     27  13   black  0       0        0    0    14581.8600
# NSW18   1     23  10   black  0       1        0    0     7693.4000
# NSW19   1     40  12   black  0       0        0    0    10804.3200
# NSW20   1     26  12   black  0       0        0    0    10747.3500
# NSW21   1     23  11   black  0       1        0    0        0.0000
# NSW22   1     41  14   white  0       0        0    0     5149.5010
# NSW23   1     38   9   white  0       1        0    0     6408.9500
# NSW24   1     24  11   black  0       1        0    0     1991.4000
# NSW25   1     18  10   black  0       1        0    0    11163.1700
# NSW26   1     29  11   black  1       1        0    0     9642.9990
# NSW27   1     25  11   black  0       1        0    0     9897.0490
# NSW28   1     27  10   hispan 0       1        0    0    11142.8700
# NSW29   1     17  10   black  0       1        0    0    16218.0400
# NSW30   1     24  11   black  0       1        0    0      995.7002
# ...     ...   ... ...  ...    ...     ...      ...  ...  ...
# PSID400 0     37   8   black  0       1        0    0      648.7220
# PSID401 0     17  10   black  0       1        0    0     1053.6190
# PSID402 0     16   8   white  0       1        0    0        0.0000
# PSID403 0     48  12   white  1       0        0    0     1491.0260
# PSID404 0     55   7   white  0       1        0    0        0.0000
# PSID405 0     21  15   white  0       0        0    0        0.0000
# PSID406 0     16  10   black  0       1        0    0     1730.4180
# PSID407 0     23  12   white  0       0        0    0     3902.6760
# PSID408 0     46  11   black  1       1        0    0        0.0000
# PSID409 0     17  10   white  0       1        0    0    14942.7700
# PSID410 0     42  16   white  0       0        0    0    23764.8000
# PSID411 0     18  10   black  0       1        0    0     5306.5160
# PSID412 0     53  12   black  0       0        0    0        0.0000
# PSID413 0     17  10   white  1       1        0    0     3859.8220
# PSID414 0     17   6   white  0       1        0    0        0.0000
# PSID415 0     43   6   white  1       1        0    0        0.0000
# PSID416 0     34  12   black  0       0        0    0        0.0000
# PSID417 0     16   8   hispan 0       1        0    0    12242.9600
# PSID418 0     27  12   white  1       0        0    0     1533.8800
# PSID419 0     51   4   black  0       1        0    0        0.0000
# PSID420 0     39   2   black  1       1        0    0      964.9555
# 600 0     43   6   0     0      1       1        0    0        0.0000
# 601 0     34  12   1     0      0       0        0    0        0.0000
# 602 0     16   8   0     1      0       1        0    0    12242.9600
# 603 0     27  12   0     0      1       0        0    0     1533.8800
# 604 0     51   4   1     0      0       1        0    0        0.0000
# 605 0     39   2   1     0      1       1        0    0      964.9555
# 606 0     55   8   0     0      1       1        0    0        0.0000
# 607 0     16   9   0     0      0       1        0    0     5551.8190
# 608 0     27  10   1     0      0       1        0    0     7543.7940
# 609 0     25  14   0     0      0       0        0    0        0.0000
# 610 0     18  11   0     0      0       1        0    0    10150.5000
# 611 0     24   1   0     1      1       1        0    0    19464.6100
# 612 0     21  18   0     0      0       0        0    0        0.0000
# 613 0     32   5   1     0      1       1        0    0      187.6713
# 614 0     16   9   0     0      0       1        0    0     1495.4590

# %% [markdown]
# # Exploring data

# %%
#looking at the income average in 78
#install.packages("dplyr")
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
dataset %>%
    group_by(treat) %>%
    summarise(mean_income_78 = mean(re78))
# Out:
#   treat mean_income_78
# 1 0     6984.170
# 2 1     6349.144

# %%
#looking at averages of the "confounders"
confounders <- c(
    "re74", 
    "re75",
    "age",
    "educ",
    "black",
    "hispan",
    "married",
    "nodegree"
)

# %%
dataset %>%
  group_by(treat) %>%
  select(one_of(confounders)) %>%
  summarise_all(list(~ mean(., na.rm = TRUE))) # The dot here means to do this to all values.
# "na.rm=TRUE" removes NA (Not Available -> null) values.
# Out:
# Adding missing grouping variables: `treat`
#   treat re74     re75     age      educ     black     hispan     married
# 1 0     5619.237 2466.484 28.03030 10.23543 0.2027972 0.14219114 0.5128205
# 2 1     2095.574 1532.055 25.81622 10.34595 0.8432432 0.05945946 0.1891892
#   nodegree
# 1 0.5967366
# 2 0.7081081

# %% [markdown]
# # T-test

# %%
#t test the continuous confounders
continuous_confounders <- c("re74", "re75", "age", "educ")

# %%
# Using $ to call a column by its name as an object.
t.test(dataset$re74 ~ dataset$treat)
# Out:
# 	Welch Two Sample t-test
#
# data:  dataset$re74 by dataset$treat
# t = 7.2456, df = 475.99, p-value = 1.748e-12
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  2568.067 4479.258
# sample estimates:
# mean in group 0 mean in group 1
#        5619.237        2095.574

# %%
# Calling a column in a "slicing-like" way.
t.test(dataset[, 're74'] ~ dataset[, 'treat'])
# Out:
# 	Welch Two Sample t-test
#
# data:  dataset[, "re74"] by dataset[, "treat"]
# t = 7.2456, df = 475.99, p-value = 1.748e-12
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  2568.067 4479.258
# sample estimates:
# mean in group 0 mean in group 1
#        5619.237        2095.574

# %% [markdown]
# A function is defined as following:
# function(variable) { WriteHereSomethingToDoWithTheVariable }

# %%
# This calls the defined function for each variable.
# Basically it does a t-test for each continuous_confounders in one go.
lapply(continuous_confounders, function(variable){
  t.test(dataset[, variable] ~ dataset[, 'treat'])})
# Out:
# [[1]]
#
# 	Welch Two Sample t-test
#
# data:  dataset[, variable] by dataset[, "treat"]
# t = 7.2456, df = 475.99, p-value = 1.748e-12
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  2568.067 4479.258
# sample estimates:
# mean in group 0 mean in group 1
#        5619.237        2095.574
#
#
# [[2]]
#
# 	Welch Two Sample t-test
#
# data:  dataset[, variable] by dataset[, "treat"]
# t = 3.2776, df = 356.22, p-value = 0.00115
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   373.742 1495.116
# sample estimates:
# mean in group 0 mean in group 1
#        2466.484        1532.055
#
#
# [[3]]
#
# 	Welch Two Sample t-test
#
# data:  dataset[, variable] by dataset[, "treat"]
# t = 2.9911, df = 510.57, p-value = 0.002914
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.7598127 3.6683610
# sample estimates:
# mean in group 0 mean in group 1
#        28.03030        25.81622
#
#
# [[4]]
#
# 	Welch Two Sample t-test
#
# data:  dataset[, variable] by dataset[, "treat"]
# t = -0.54676, df = 485.37, p-value = 0.5848
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.5076687  0.2866393
# sample estimates:
# mean in group 0 mean in group 1
#        10.23543        10.34595

# %% [markdown]
# # Computing Propensities

# %%
#create model to compute propensities
model_propensity <- glm(treat ~ re74 + re75 + age + educ +
                          black + hispan + married + nodegree,
                        family = "binomial",
                        data = dataset)
summary(model_propensity)
# Out:
# Call:
# glm(formula = treat ~ re74 + re75 + age + educ + black + hispan +
#     married + nodegree, family = "binomial", data = dataset)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.7645  -0.4736  -0.2862   0.7508   2.7169
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -4.729e+00  1.017e+00  -4.649 3.33e-06 ***
# re74        -7.178e-05  2.875e-05  -2.497  0.01253 *
# re75         5.345e-05  4.635e-05   1.153  0.24884
# age          1.578e-02  1.358e-02   1.162  0.24521
# educ         1.613e-01  6.513e-02   2.477  0.01325 *
# black        3.065e+00  2.865e-01  10.699  < 2e-16 ***
# hispan       9.836e-01  4.257e-01   2.311  0.02084 *
# married     -8.321e-01  2.903e-01  -2.866  0.00415 **
# nodegree     7.073e-01  3.377e-01   2.095  0.03620 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 751.49  on 613  degrees of freedom
# Residual deviance: 487.84  on 605  degrees of freedom
# AIC: 505.84
#
# Number of Fisher Scoring iterations: 5

# %%
#create dataframe for common support region
propensity_scores <- predict(model_propensity, type = "response")
propensity_dataframe <- data.frame(propensity_score = propensity_scores,
                                   treat = model_propensity$model$treat)

# %%
propensity_dataframe
# Out:
#     propensity_score treat
# 1   0.63876993       1
# 2   0.22463424       1
# 3   0.67824388       1
# 4   0.77632408       1
# 5   0.70163874       1
# 6   0.69906990       1
# 7   0.65368426       1
# 8   0.78972311       1
# 9   0.77983825       1
# 10  0.04292461       1
# 11  0.68901996       1
# 12  0.68244400       1
# 13  0.64986767       1
# 14  0.56241073       1
# 15  0.60858629       1
# 16  0.72249036       1
# 17  0.70259562       1
# 18  0.73496416       1
# 19  0.71166489       1
# 20  0.66431981       1
# 21  0.76517492       1
# 22  0.13901525       1
# 23  0.12238224       1
# 24  0.76799791       1
# 25  0.71931601       1
# 26  0.60916715       1
# 27  0.77079713       1
# 28  0.26920316       1
# 29  0.71611962       1
# 30  0.76799791       1
# ... ...              ...
# 585 0.71467967       0
# 586 0.71611962       0
# 587 0.07738177       0
# 588 0.05376946       0
# 589 0.11665805       0
# 590 0.12156128       0
# 591 0.71290136       0
# 592 0.08090646       0
# 593 0.67084800       0
# 594 0.10526247       0
# 595 0.18465798       0
# 596 0.71931601       0
# 597 0.75186535       0
# 598 0.04869832       0
# 599 0.05812367       0
# 600 0.03889528       0
# 601 0.69185828       0
# 602 0.18319778       0
# 603 0.03919964       0
# 604 0.62101848       0
# 605 0.29939542       0
# 606 0.06325293       0
# 607 0.08971192       0
# 608 0.74707356       0
# 609 0.11145877       0
# 610 0.12314388       0
# 611 0.03456038       0
# 612 0.18335100       0
# 613 0.38303231       0
# 614 0.08971192       0

# %% [markdown]
# # Visualizing

# %%
#visualizing common support region
#install.packages("ggplot2")
library(ggplot2)
propensity_dataframe %>%
  ggplot(aes(x = propensity_score)) +
  facet_wrap(~ treat) + 
  geom_histogram() +
  xlab("Propensity score")
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# # Matching

# %%
#matching
matching <- matchit(treat ~ re74 + re75 + age + educ +
                      black + hispan + married + nodegree,
                    data = dataset,
                    method = "nearest",
                    replace = TRUE,
                    discard = "both")
summary(matching)
# Out:
# Call:
# matchit(formula = treat ~ re74 + re75 + age + educ + black +
#     hispan + married + nodegree, data = dataset, method = "nearest",
#     discard = "both", replace = TRUE)
#
# Summary of Balance for All Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance        0.5774        0.1822          1.7941     0.9211    0.3774
# re74         2095.5737     5619.2365         -0.7211     0.5181    0.2248
# re75         1532.0553     2466.4844         -0.2903     0.9563    0.1342
# age            25.8162       28.0303         -0.3094     0.4400    0.0813
# educ           10.3459       10.2354          0.0550     0.4959    0.0347
# black           0.8432        0.2028          1.7615          .    0.6404
# hispan          0.0595        0.1422         -0.3498          .    0.0827
# married         0.1892        0.5128         -0.8263          .    0.3236
# nodegree        0.7081        0.5967          0.2450          .    0.1114
#          eCDF Max
# distance   0.6444
# re74       0.4470
# re75       0.2876
# age        0.1577
# educ       0.1114
# black      0.6404
# hispan     0.0827
# married    0.3236
# nodegree   0.1114
#
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance        0.5669        0.5669          0.0003     0.9830    0.0028
# re74         2179.3904     2417.1266         -0.0487     1.0567    0.0441
# re75         1485.9177     1389.1992          0.0300     2.2041    0.0616
# age            25.4463       24.2655          0.1650     0.5125    0.0770
# educ           10.3220       10.3503         -0.0140     0.5759    0.0229
# black           0.8362        0.8305          0.0155          .    0.0056
# hispan          0.0621        0.0678         -0.0239          .    0.0056
# married         0.1977        0.1356          0.1587          .    0.0621
# nodegree        0.6949        0.6893          0.0124          .    0.0056
#          eCDF Max Std. Pair Dist.
# distance   0.0508          0.0097
# re74       0.2316          0.6325
# re75       0.2260          0.6279
# age        0.3164          1.2342
# educ       0.0621          1.1324
# black      0.0056          0.0466
# hispan     0.0056          0.3106
# married    0.0621          0.5337
# nodegree   0.0056          0.9072
#
# Percent Balance Improvement:
#          Std. Mean Diff. Var. Ratio eCDF Mean eCDF Max
# distance           100.0       79.2      99.3     92.1
# re74                93.3       91.6      80.4     48.2
# re75                89.6    -1668.4      54.1     21.4
# age                 46.7       18.6       5.4   -100.6
# educ                74.4       21.3      34.1     44.2
# black               99.1          .      99.1     99.1
# hispan              93.2          .      93.2     93.2
# married             80.8          .      80.8     80.8
# nodegree            94.9          .      94.9     94.9
#
# Sample Sizes:
#               Control Treated
# All            429.       185
# Matched (ESS)   44.31     177
# Matched         80.       177
# Unmatched      292.         0
# Discarded       57.         8

# %%
#create dataframe with just matched data
matched_data <- match.data(matching)

# %%
matched_data
# Out:
#     treat age educ black hispan married nodegree re74      re75 re78
# 575 0     48  13   0     0      1       0           0.0000 0        0.0000
# 577 0     17  10   1     0      0       1           0.0000 0        0.0000
# 580 0     53  12   0     0      0       0           0.0000 0        0.0000
# 584 0     27  14   1     0      0       0           0.0000 0    10122.4300
# 591 0     16  10   1     0      0       1           0.0000 0     1730.4180
# 608 0     27  10   1     0      0       1           0.0000 0     7543.7940
# 613 0     32   5   1     0      1       1           0.0000 0      187.6713
#     distance   weights
# 1   0.63876993 1
# 2   0.22463424 1
# 3   0.67824388 1
# 4   0.77632408 1
# 5   0.70163874 1
# 6   0.69906990 1
# 7   0.65368426 1
# 9   0.77983825 1
# 10  0.04292461 1
# 11  0.68901996 1
# 12  0.68244400 1
# 13  0.64986767 1
# 14  0.56241073 1
# 15  0.60858629 1
# 16  0.72249036 1
# 17  0.70259562 1
# 18  0.73496416 1
# 19  0.71166489 1
# 20  0.66431981 1
# 21  0.76517492 1
# 22  0.13901525 1
# 23  0.12238224 1
# 24  0.76799791 1
# 25  0.71931601 1
# 26  0.60916715 1
# 27  0.77079713 1
# 28  0.26920316 1
# 29  0.71611962 1
# 30  0.76799791 1
# 31  0.71611962 1
# ... ...        ...
# 520 0.61099700 1.3559322
# 522 0.61143145 0.4519774
# 526 0.20130824 0.4519774
# 527 0.10027830 0.4519774
# 529 0.04301213 0.9039548
# 530 0.66289776 2.7118644
# 537 0.64803402 0.4519774
# 539 0.44466699 0.4519774
# 541 0.43739641 0.4519774
# 550 0.07738177 0.4519774
# 552 0.71931601 3.6158192
# 553 0.64961800 0.9039548
# 555 0.67878861 0.4519774
# 556 0.11303087 0.4519774
# 558 0.64289289 0.4519774
# 559 0.75070545 0.9039548
# 560 0.67084800 0.4519774
# 561 0.64626932 2.7118644
# 565 0.49417728 0.4519774
# 566 0.68244400 0.4519774
# 569 0.12972391 0.9039548
# 572 0.63575388 0.9039548
# 573 0.75364638 1.3559322
# 575 0.06259243 0.4519774
# 577 0.71611962 2.2598870
# 580 0.12381573 0.4519774
# 584 0.73516648 1.3559322
# 591 0.71290136 0.4519774
# 608 0.74707356 0.4519774
# 613 0.38303231 0.9039548

# %% [markdown]
# # Analyzing matches

# %%
#looking at averages of the confounders in the matched dataset
matched_data %>%
  group_by(treat) %>%
  select(one_of(confounders)) %>%
  summarise_all(list(~ mean(., na.rm = TRUE)))
# Out:
# Adding missing grouping variables: `treat`
#   treat re74     re75     age      educ     black     hispan     married
# 1 0     2264.447 1627.739 25.07500 10.37500 0.6875000 0.12500000 0.2125000
# 2 1     2179.390 1485.918 25.44633 10.32203 0.8361582 0.06214689 0.1977401
#   nodegree
# 1 0.6375000
# 2 0.6949153

# %%
#t test the continuous confounders in the matched dataset
lapply(continuous_confounders, function(variable){
  t.test(matched_data[, variable] ~ matched_data[, 'treat'])})
# Out:
# [[1]]
#
# 	Welch Two Sample t-test
#
# data:  matched_data[, variable] by matched_data[, "treat"]
# t = 0.13733, df = 170.61, p-value = 0.8909
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1137.560  1307.673
# sample estimates:
# mean in group 0 mean in group 1
#        2264.447        2179.390
#
#
# [[2]]
#
# 	Welch Two Sample t-test
#
# data:  matched_data[, variable] by matched_data[, "treat"]
# t = 0.37169, df = 183.42, p-value = 0.7106
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -610.9877  894.6299
# sample estimates:
# mean in group 0 mean in group 1
#        1627.739        1485.918
#
#
# [[3]]
#
# 	Welch Two Sample t-test
#
# data:  matched_data[, variable] by matched_data[, "treat"]
# t = -0.29176, df = 112.69, p-value = 0.771
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.892917  2.150262
# sample estimates:
# mean in group 0 mean in group 1
#        25.07500        25.44633
#
#
# [[4]]
#
# 	Welch Two Sample t-test
#
# data:  matched_data[, variable] by matched_data[, "treat"]
# t = 0.15468, df = 120.79, p-value = 0.8773
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6249472  0.7308794
# sample estimates:
# mean in group 0 mean in group 1
#        10.37500        10.32203

# %% [markdown]
# # Checking Results (?)

# %%
#checking impact of the training in the income of 78
impact_training <- lm(re78 ~ treat + re74 + re75 + age + educ +
                        black + hispan + married + nodegree, 
                      data = matched_data)
summary(impact_training)
# Out:
# Call:
# lm(formula = re78 ~ treat + re74 + re75 + age + educ + black +
#     hispan + married + nodegree, data = matched_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -8951  -4881  -1726   3514  27340
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.334e+02  3.951e+03  -0.059   0.9529
# treat        1.561e+03  8.775e+02   1.779   0.0764 .
# re74         6.384e-02  1.138e-01   0.561   0.5755
# re75         1.768e-01  1.807e-01   0.979   0.3287
# age          2.763e+01  5.416e+01   0.510   0.6105
# educ         4.406e+02  2.483e+02   1.775   0.0771 .
# black       -1.043e+03  1.240e+03  -0.842   0.4009
# hispan      -4.074e+02  1.834e+03  -0.222   0.8244
# married      3.987e+02  1.105e+03   0.361   0.7185
# nodegree    -1.155e+02  1.218e+03  -0.095   0.9245
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6401 on 247 degrees of freedom
# Multiple R-squared:  0.06313,	Adjusted R-squared:  0.02899
# F-statistic: 1.849 on 9 and 247 DF,  p-value: 0.06026

# %% [markdown]
# The class' instructor recommends re-doing the matching excluding one variable and see if it affects the results. Removing "re74" for example makes treat variable lose all significance.

# %% [markdown]
# # Matching without "re74"

# %%
matching <- matchit(treat ~ re75 + age + educ +
                      black + hispan + married + nodegree,
                    data = dataset,
                    method = "nearest",
                    replace = TRUE,
                    discard = "both")

matched_data <- match.data(matching)

impact_training <- lm(re78 ~ treat + re74 + re75 + age + educ +
                        black + hispan + married + nodegree, 
                      data = matched_data)
summary(impact_training)
# Out:
# Call:
# lm(formula = re78 ~ treat + re74 + re75 + age + educ + black +
#     hispan + married + nodegree, data = matched_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -10811  -5136  -1851   3352  54241
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.431e+03  4.693e+03   0.305    0.761
# treat        6.412e+02  1.078e+03   0.595    0.553
# re74         9.157e-02  1.154e-01   0.793    0.428
# re75         1.699e-01  1.891e-01   0.899    0.370
# age          6.981e+01  6.243e+01   1.118    0.265
# educ         3.887e+02  2.991e+02   1.300    0.195
# black       -2.077e+03  1.467e+03  -1.416    0.158
# hispan      -1.037e+03  2.119e+03  -0.489    0.625
# married      3.480e+02  1.264e+03   0.275    0.783
# nodegree    -3.777e+02  1.470e+03  -0.257    0.797
#
# Residual standard error: 7470 on 247 degrees of freedom
# Multiple R-squared:  0.05952,	Adjusted R-squared:  0.02525
# F-statistic: 1.737 on 9 and 247 DF,  p-value: 0.08128
